# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('../Datasets/ADS/total_training_data.csv')
train_df.head()
# Out:
#            0         1          2          3          4         5          6  \
# 0  33.883310  0.188470  31.197649  31.198807  31.237043  0.039394  39.990345
# 1  23.442284  0.015231  23.083265  23.519197  23.799660  0.716394   0.000000
# 2  26.658195  0.095594  24.275490  27.404346  29.017082  4.741592  61.829530
# 3   0.000000  0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 4  34.614662  0.005980  34.433628  34.559757  34.764160  0.330532   8.279264
#
#            7           8          9  ...        81        82        83  \
# 0  28.040092  100.798780   0.000000  ...  1.960784  2.061856  0.240000
# 1   0.000000   -0.109734   0.000000  ...  3.703704  2.040816  0.080000
# 2  67.673560   20.461290  11.705440  ...  3.131991  2.036199  0.344444
# 3   0.000000    0.000000   0.000000  ...  3.333334  0.000000  0.000000
# 4   5.828207    8.208370   6.596444  ...  5.084746  1.886793  0.420000
#
#          84     85        86         87  participant_id  Depression  Gender
# ...

# %% [markdown]
# Looks like the column names are just numbered. Since we have the `feature_description.csv`, we can use that to add names to our variable columns

# %%
feature_description = pd.read_csv('../Datasets/source/feature_description.csv', header=None)
feature_description.columns = ['Feature_Name','Feature_Detail']
feature_description
# Out:
#                                   Feature_Name  \
# 0            F0semitoneFrom27.5Hz_sma3nz_amean
# 1       F0semitoneFrom27.5Hz_sma3nz_stddevNorm
# 2   F0semitoneFrom27.5Hz_sma3nz_percentile20.0
# 3   F0semitoneFrom27.5Hz_sma3nz_percentile50.0
# 4   F0semitoneFrom27.5Hz_sma3nz_percentile80.0
# ..                                         ...
# 83                  MeanVoicedSegmentLengthSec
# 84                StddevVoicedSegmentLengthSec
# 85                   MeanUnvoicedSegmentLength
# 86                 StddevUnvoicedSegmentLength
# 87                    equivalentSoundLevel_dBp
#
#                                        Feature_Detail
# 0   mean logarithmic F0 on a semitone frequency sc...
# 1   standard deviation of logarithmic F0 on a semi...
# 2   20th percentile of logarithmic F0 on a semiton...
# 3   50th percentile of logarithmic F0 on a semiton...
# 4   80th percentile of logarithmic F0 on a semiton...
# ..                                                ...
# ...

# %%
train_df = train_df.rename(columns=dict(zip(train_df.columns[:88], feature_description['Feature_Name'])))
train_df.columns
# Out:
# Index(['F0semitoneFrom27.5Hz_sma3nz_amean',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevNorm',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile20.0',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile50.0',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile80.0',
#        'F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2',
#        'F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope', 'loudness_sma3_amean',
#        'loudness_sma3_stddevNorm', 'loudness_sma3_percentile20.0',
#        'loudness_sma3_percentile50.0', 'loudness_sma3_percentile80.0',
#        'loudness_sma3_pctlrange0-2', 'loudness_sma3_meanRisingSlope',
#        'loudness_sma3_stddevRisingSlope', 'loudness_sma3_meanFallingSlope',
#        'loudness_sma3_stddevFallingSlope', 'spectralFlux_sma3_amean',
#        'spectralFlux_sma3_stddevNorm', 'mfcc1_sma3_amean',
# ...

# %%
test_df = pd.read_csv('../Datasets/ADS/total_testing_data.csv')
test_df.head()
# Out:
#            0         1          2          3          4         5          6  \
# 0  31.240383  0.007705  31.195211  31.197490  31.198797  0.003586   2.502873
# 1  25.895664  0.022401  25.307716  26.016266  26.448654  1.140938   0.185591
# 2  25.333618  0.093532  23.294510  24.970371  27.738895  4.444386  62.354210
# 3  22.731540  0.048258  22.157387  22.643700  23.537909  1.380522  43.013565
# 4  22.226995  0.036559  21.806602  22.638226  22.795425  0.988823   6.112480
#
#            7          8          9  ...        81        82        83  \
# 0   2.195133   6.924655   0.000000  ...  2.352941  2.531646  0.270000
# 1   0.000000   0.000000   0.000000  ...  5.000000  1.818182  0.080000
# 2  62.804974  11.951715  16.090214  ...  3.004292  2.631579  0.196667
# 3  45.249077  12.193955   4.822075  ...  4.024768  2.656250  0.175882
# 4   2.537038  10.932255   0.000000  ...  7.142857  3.174603  0.150000
#
#          84        85        86         87  participant_id  Depression  Gender
# ...

# %%
test_df = test_df.rename(columns=dict(zip(test_df.columns[:88], feature_description['Feature_Name'])))
test_df.columns
# Out:
# Index(['F0semitoneFrom27.5Hz_sma3nz_amean',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevNorm',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile20.0',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile50.0',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile80.0',
#        'F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2',
#        'F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope', 'loudness_sma3_amean',
#        'loudness_sma3_stddevNorm', 'loudness_sma3_percentile20.0',
#        'loudness_sma3_percentile50.0', 'loudness_sma3_percentile80.0',
#        'loudness_sma3_pctlrange0-2', 'loudness_sma3_meanRisingSlope',
#        'loudness_sma3_stddevRisingSlope', 'loudness_sma3_meanFallingSlope',
#        'loudness_sma3_stddevFallingSlope', 'spectralFlux_sma3_amean',
#        'spectralFlux_sma3_stddevNorm', 'mfcc1_sma3_amean',
# ...

# %%
train_df
# Out:
#        F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              33.883310
# 1                              23.442284
# 2                              26.658195
# 3                               0.000000
# 4                              34.614662
# ...                                  ...
# 13621                          24.210863
# 13622                          24.474560
# 13623                          23.050886
# 13624                          23.157020
# 13625                          25.845377
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                    0.188470
# 1                                    0.015231
# 2                                    0.095594
# 3                                    0.000000
# 4                                    0.005980
# ...                                       ...
# 13621                                0.074315
# 13622                                0.042466
# ...

# %%
#Save the files
train_df.to_csv('../Datasets/ADS/final_training_data.csv')
test_df.to_csv('../Datasets/ADS/final_testing_data.csv')

# %%
import random
#Randomly sample 17 unique participant IDs from train_data for our validation set 
# val_participant_ids = random.sample(train_df['participant_id'].unique().tolist(), 20)
# df_val_participant_ids = pd.DataFrame({'participant_id': val_participant_ids})
# df_val_participant_ids.to_csv("../Datasets/validation_participant_ids.csv")
